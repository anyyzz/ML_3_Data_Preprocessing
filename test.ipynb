# %%
import pandas as pd

# %%
print("I installed pandas")
# Out:
# I installed pandas

# %%
# !python -m pip freeze > requirements.txt

# %%
# !python -m pip install -r requirements.txt
# Out:
# Processing c:\home\conda\feedstock_root\build_artifacts\asttokens_1763409923949\work (from -r requirements.txt (line 1))
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\home\\conda\\feedstock_root\\build_artifacts\\asttokens_1763409923949\\work'

# %%
# !pip install <name of lib>
